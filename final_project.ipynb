# %% [markdown]
# # VIRAT VS BABAR ANALYSIS AND PREDICTION

# %% [markdown]
# ## ANALYSIS OF VIRAT

# %% [markdown]
# **IMPORTING THE REQUIRED LIBRARIES**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **IMPORTING THE REQUIRED DATASETS**

# %%
vdataset = pd.read_csv('cvirat.csv')
vx = vdataset.iloc[:, :-1].values
vy = vdataset.iloc[:, -1].values

# %%
print("CAREER RECORD OF VIRAT KOHLI\n\n",vdataset)
# Out:
# CAREER RECORD OF VIRAT KOHLI
#
#      YEAR  INNINGS  AVERAGE  STRIKE RATE  HUNDRED  FIFTY  HIGH SCORE  ODI RUNS
# 0      1        5    31.80        66.53        0      1          54       159
# 1      2        8    54.17        84.42        1      2         107       325
# 2      3       24    47.38        85.12        3      7         118       995
# 3      4       34    47.62        85.56        4      8         117      1381
# 4      5       17    68.40        93.78        5      3         183      1026
# 5      6       30    52.83        97.54        4      7         115      1268
# 6      7       20    58.56        99.62        4      5         139      1054
# 7      8       20    36.65        80.60        2      1         138       623
# 8     10       10    92.38       100.00        3      4         154       739
# 9     11       26    76.84        99.12        6      7         131      1460
# 10    12       14   133.56       102.56        6      3         160      1202
# ...

# %% [markdown]
# ## GRAPH ANALYSIS

# %% [markdown]
# **TOTAL RUNS**

# %%
x=vdataset["YEAR"]
y=vdataset["ODI RUNS"]

plt.plot(x,y,color="blue")
plt.title("Virat's Career")
plt.xlabel("No. of years from debut")
plt.ylabel("Total Run Per Year")
# Out:
# Text(0, 0.5, 'Total Run Per Year')

# %% [markdown]
# **HIGHEST RUNS**

# %%
x=vdataset["YEAR"]
y=vdataset["HIGH SCORE"]
plt.plot(x,y,color="blue")
plt.title("Virat's Career")
plt.xlabel("No. of years from debut")
plt.ylabel("Highest Score On That Year")
# Out:
# Text(0, 0.5, 'Highest Score On That Year')

# %% [markdown]
# **AVERAGE**

# %%
x=vdataset["YEAR"]
y=vdataset["AVERAGE"]
plt.plot(x,y,color="blue")
plt.title("Virat's Career")
plt.xlabel("No. of years from debut")
plt.ylabel("AVERAGE")
# Out:
# Text(0, 0.5, 'AVERAGE')

# %% [markdown]
# **SUMMARY**

# %%
print("VIRAT'S CAREER" "\nTotal Innings",vdataset["INNINGS"].sum(), "\nTotal ODI Hundreds",vdataset["HUNDRED"].sum(),"\nTotal Fifty",vdataset["FIFTY"].sum(),sep=" ")
print("Career Average",vdataset["AVERAGE"].mean(),"\nCareer Strike Rate",vdataset["STRIKE RATE"].mean())
# Out:
# VIRAT'S CAREER
# Total Innings 253
# Total ODI Hundreds 43
# Total Fifty 64
# Career Average 58.186666666666675
# Career Strike Rate 89.63533333333332

# %% [markdown]
# ## ANALYSIS OF BABAR

# %% [markdown]
# **IMPORTING THE REQUIRED DATASETS**

# %%
bdataset = pd.read_csv('ccbabar.csv')
bx = bdataset.iloc[:, :-1].values
by = bdataset.iloc[:, -1].values

# %%
print("CAREER RECORD OF BABAR AZAM\n\n",bdataset)
# Out:
# CAREER RECORD OF BABAR AZAM
#
#     YEAR  INNINGS  AVERAGE  STRIKE RATE  HUNDRED  FIFTY  HIGH SCORE  ODI RUNS
# 0     1        7     38.3         89.1        0      3          62       230
# 1     2       11     59.6         95.2        3      2         123       656
# 2     3       17     67.1         79.3        4      2         125       872
# 3     4       17     36.4         81.2        1      2         106       509
# 4     5       20     60.7         92.3        3      6         115      1092
# 5     6        3    110.5        101.8        1      1         125       221
# 6     7        6     67.5        108.0        2      1         158       405
# 7     8        9     84.9         90.8        3      5         114       679

# %% [markdown]
# # GRAPH ANALYSIS

# %% [markdown]
# **TOTAL RUNS**

# %%
x=bdataset["YEAR"]
y=bdataset["ODI RUNS"]

plt.plot(x,y,color="green")
plt.title("Babar's Career")
plt.xlabel("No. of years from debut")
plt.ylabel("Total Run Per Year")
# Out:
# Text(0, 0.5, 'Total Run Per Year')

# %% [markdown]
# **HIGHEST RUNS**

# %%
x=bdataset["YEAR"]
y=bdataset["HIGH SCORE"]
plt.plot(x,y,color="green")
plt.title("babar's Career")
plt.xlabel("No. of years from debut")
plt.ylabel("Highest Score On That Year")
# Out:
# Text(0, 0.5, 'Highest Score On That Year')

# %% [markdown]
# **AVERAGE**

# %%
x=bdataset["YEAR"]
y=bdataset["AVERAGE"]
plt.plot(x,y,color="green")
plt.title("Babar's Career")
plt.xlabel("No. of years from debut")
plt.ylabel("AVERAGE")
# Out:
# Text(0, 0.5, 'AVERAGE')

# %% [markdown]
# **SUMMARY**

# %%
print("BABAR'S CAREER" "\nTotal Innings",bdataset["INNINGS"].sum(), "\nTotal ODI Hundreds",bdataset["HUNDRED"].sum(),"\nTotal Fifty",bdataset["FIFTY"].sum(),sep=" ")
print("Career Average",bdataset["AVERAGE"].mean(),"\nCareer Strike Rate",bdataset["STRIKE RATE"].mean())
# Out:
# BABAR'S CAREER
# Total Innings 90
# Total ODI Hundreds 17
# Total Fifty 22
# Career Average 65.625
# Career Strike Rate 92.21249999999999

# %% [markdown]
# # VIRAT KOHLI PREDICTION USING MULTIPLE LINEAR REGRESSION

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
vX_train, vX_test, vy_train, vy_test = train_test_split(vx, vy, test_size = 0.2, random_state = 0)

# %% [markdown]
# ## Training the Multiple Linear Regression model on the Training set

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(vX_train, vy_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Predicting the Test set results

# %%
vy_pred = regressor.predict(vX_test)
np.set_printoptions(precision=2)
print(np.concatenate((vy_pred.reshape(len(vy_pred),1), vy_test.reshape(len(vy_test),1)),1))
# Out:
# [[ 369.08  325.  ]
#  [1042.04 1054.  ]
#  [ 772.41  739.  ]]

# %% [markdown]
# ## Evaluating the Model Performance

# %%
from sklearn.metrics import r2_score
r2_score(vy_test, vy_pred)
# Out:
# 0.9880230850718993

# %% [markdown]
# # BABAR AZAM PREDICTION USING RANDOM FOREST REGRESSION

# %%
from sklearn.model_selection import train_test_split
bX_train, bX_test, by_train, by_test = train_test_split(bx, by, test_size = 0.2, random_state = 0)

# %% [markdown]
# ## Training the Random Forest Regression model on the whole dataset

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(bX_train, by_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %% [markdown]
# ## Predicting the Test set results

# %%
by_pred = regressor.predict(bX_test)
np.set_printoptions(precision=2)
print(np.concatenate((by_pred.reshape(len(by_pred),1), by_test.reshape(len(by_test),1)),1))
# Out:
# [[310.3 405. ]
#  [686.7 872. ]]

# %% [markdown]
# ## Evaluating the Model Performance

# %%
from sklearn.metrics import r2_score
r2_score(by_test, by_pred)
# Out:
# 0.6028760735296143

# %%
regressor.predict(bX_test)
# Out:
# array([310.3, 686.7])
